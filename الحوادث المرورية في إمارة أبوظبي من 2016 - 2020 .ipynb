# %% [markdown]
# # الحوادث المرورية في إمارة أبوظبي من 2016-2020

# %%
import  pandas as pd
import numpy as np

# %%
pd.set_option("display.max_rows", 999)

# %%
df16 = pd.read_excel("traffic accidents -2016.xlsx")
df17 = pd.read_excel("traffic accidents -2017.xlsx")
df18 = pd.read_excel("traffic accidents -2018.xlsx")
df19 = pd.read_excel("traffic accidents -2019.xlsx")
df20 = pd.read_excel("traffic accidents -2020.xlsx")

# %%
df16.head()
# Out:
#   Rep Date\nتاريخ الحادث  \nRep Year\n سنة الحادث\n  \
# 0             13/01/2016                       2016
# 1             13/01/2016                       2016
# 2             13/01/2016                       2016
# 3             13/01/2016                       2016
# 4             13/01/2016                       2016
#
#   Rep Kine\n نوع تقرير الحادث City\n المدينة           Street \nالشارع  \
# 0            حادث سير بإصابات         ابوظبي  شارع الشيخ مكتوم بن راشد
# 1            حادث سير بإصابات         ابوظبي                 شارع ياس1
# 2            حادث سير بإصابات         ابوظبي       طريق أبوظبي - العين
# 3            حادث سير بإصابات         ابوظبي               طريق المصفح
# 4            حادث سير بإصابات   منطقة الظفرة                 شارع حميم
#
#       Rep TYPE\n نوع الحادث                 Reason\n سبب الحادث  \
# 0  صدم جسم ثابت خارج الطريق                    الإنحراف المفاجئ
# 1         صدم إثناء الدوران  دخول طريق رئيسي دون التأكد من خلوه
# ...

# %%
df17.head()
# Out:
#   Rep Date\nتاريخ الحادث  \nRep Year\n سنة الحادث\n  \
# 0    2017-01-01 00:00:00                       2017
# 1    2017-01-01 00:00:00                       2017
# 2    2017-01-01 00:00:00                       2017
# 3    2017-01-01 00:00:00                       2017
# 4    2017-01-01 00:00:00                       2017
#
#   Rep Kine\n نوع تقرير الحادث City\n المدينة      Street \nالشارع  \
# 0            حادث سير بإصابات         ابوظبي      شارع الشيخ زايد
# 1            حادث سير بإصابات         ابوظبي  طريق أبوظبي - العين
# 2            حادث سير بإصابات         ابوظبي          طريق المصفح
# 3            حادث سير بإصابات         ابوظبي          طريق سويحان
# 4            حادث سير بإصابات         ابوظبي            طريق طريف
#
#   Rep TYPE\n نوع الحادث             Reason\n سبب الحادث Surface \nحالة السطح  \
# 0             صدم عمودي  القيادة تحت تأثير مسكر أو مخدر                  جاف
# 1             دهس إنسان   السرعة دون مراعاة ظروف الطريق                  جاف
# ...

# %%
df18.head()
# Out:
#   Rep Date\nتاريخ الحادث  \nRep Year\n سنة الحادث\n Rep Kine نوع تقرير الحادث  \
# 0             31/12/2018                       2018          حادث سير بإصابات
# 1             31/12/2018                       2018          حادث سير بإصابات
# 2             31/12/2018                       2018          حادث سير بإصابات
# 3             31/12/2018                       2018      حادث سير بدون إصابات
# 4             31/12/2018                       2018      حادث سير بدون إصابات
#
#   City\n المدينة                                    Street \nالشارع  \
# 0         ابوظبي                     شارع راشد بن سعيد آل مكتوم (2)
# 1         ابوظبي  IP11C شارع بني ياس (النجدة) (تقاطع وكالة المسعود)
# 2    منطقة العين                       تقاطع إشارات العين / البريمي
# 3         ابوظبي                             IP38C تقاطع أبوظبي مول
# 4         ابوظبي                                    IP6A زايد الأول
#
#       Rep TYPE\n نوع الحادث                   Reason\n سبب الحادث  \
# ...

# %%
df19.head()
# Out:
#   Rep Date\nتاريخ الحادث  \nRep Year\n سنة الحادث\n  \
# 0    2019-02-10 00:00:00                       2019
# 1    2019-02-10 00:00:00                       2019
# 2    2019-02-10 00:00:00                       2019
# 3    2019-02-10 00:00:00                       2019
# 4    2019-02-10 00:00:00                       2019
#
#   Rep Kine \nنوع تقرير الحادث City\n المدينة             Street \nالشارع  \
# 0            حادث سير بإصابات   منطقة الظفرة        شارع المقاطرة - حميم
# 1            حادث سير بإصابات    منطقة العين  شارع زايد بن سلطان (العام)
# 2            حادث سير بإصابات         أبوظبي         شارع المفرق الشوامخ
# 3            حادث سير بإصابات         أبوظبي         شارع المفرق الشوامخ
# 4            حادث سير بإصابات         أبوظبي         طريق أبوظبي - العين
#
#     Rep TYPE\n نوع الحادث                                Reason\n سبب الحادث  \
# 0                   تدهور  الانشغال عن الطريق أثناء قيادة المركبة باستعما...
# ...

# %%
df20.head()
# Out:
#   Rep Date\nتاريخ الحادث  \nRep Year\n سنة الحادث\n Rep Kine نوع تقرير الحادث  \
# 0             17/03/2020                       2020          حادث سير بإصابات
# 1             17/03/2020                       2020          حادث سير بإصابات
# 2             17/03/2020                       2020          حادث سير بإصابات
# 3             17/03/2020                       2020          حادث سير بإصابات
# 4             17/03/2020                       2020          حادث سير بإصابات
#
#   City\n المدينة                                  Street \nالشارع  \
# 0   منطقة الظفرة                                       شارع غياثي
# 1    منطقة العين                               شارع خليفة بن زايد
# 2         أبوظبي                         شارع الشيخ مكتوم بن راشد
# 3         أبوظبي                                      طريق المصفح
# 4         أبوظبي  IP11A شارع السلام (تقاطع جهاز الرقابة الغذائية)
#
#       Rep TYPE\n نوع الحادث  \
# 0                 صدم جانبي
# 1                 صدم جانبي
# ...

# %%
columns = ['تاريخ الحادث', 'سنة الحادث', 'نوع تقرير الحادث' , 'المدينة','الشارع' ,'نوع الحادث' , 'سبب الحادث', 'حالة السطح' ,'حالة الطقس' ,'عدد الحوادث' ,'عدد الاصابات']
df16.columns = columns
df17.columns = columns
df18.columns = columns
df19.columns = columns
df20.columns = columns

# %%
# df16[df16.duplicated()]
# df17[df17.duplicated()]
# df18[df18.duplicated()]
# df19[df19.duplicated()]
# df20[df20.duplicated()]

# %%
repeat16 = np.repeat(df16.index.values,df16['عدد الحوادث'])
df16repeat = df16.iloc[repeat16].reset_index(drop=True)
df16repeat
# Out:
#                تاريخ الحادث  سنة الحادث      نوع تقرير الحادث       المدينة  \
# 0                13/01/2016        2016      حادث سير بإصابات        ابوظبي
# 1                13/01/2016        2016      حادث سير بإصابات        ابوظبي
# 2                13/01/2016        2016      حادث سير بإصابات        ابوظبي
# 3                13/01/2016        2016      حادث سير بإصابات        ابوظبي
# 4                13/01/2016        2016      حادث سير بإصابات  منطقة الظفرة
# ...                     ...         ...                   ...           ...
# 231961  2016-12-12 00:00:00        2016  حادث سير بدون إصابات   منطقة العين
# 231962  2016-12-12 00:00:00        2016  حادث سير بدون إصابات   منطقة العين
# 231963  2016-12-12 00:00:00        2016  حادث سير بدون إصابات   منطقة العين
# 231964  2016-12-12 00:00:00        2016  حادث سير بدون إصابات   منطقة العين
# 231965  2016-12-12 00:00:00        2016  حادث سير بدون إصابات   منطقة العين
#
# ...

# %%
repeat17 = np.repeat(df17.index.values,df17['عدد الحوادث'])
df17repeat = df17.iloc[repeat17].reset_index(drop=True)
df17repeat
# Out:
#                تاريخ الحادث  سنة الحادث      نوع تقرير الحادث      المدينة  \
# 0       2017-01-01 00:00:00        2017      حادث سير بإصابات       ابوظبي
# 1       2017-01-01 00:00:00        2017      حادث سير بإصابات       ابوظبي
# 2       2017-01-01 00:00:00        2017      حادث سير بإصابات       ابوظبي
# 3       2017-01-01 00:00:00        2017      حادث سير بإصابات       ابوظبي
# 4       2017-01-01 00:00:00        2017      حادث سير بإصابات       ابوظبي
# ...                     ...         ...                   ...          ...
# 212073           16/05/2017        2017  حادث سير بدون إصابات  منطقة العين
# 212074           16/05/2017        2017  حادث سير بدون إصابات  منطقة العين
# 212075           16/05/2017        2017  حادث سير بدون إصابات  منطقة العين
# 212076           16/05/2017        2017  حادث سير بدون إصابات  منطقة العين
# 212077           16/05/2017        2017  حادث سير بدون إصابات  منطقة العين
#
#                      الشارع              نوع الحادث  \
# ...

# %%
repeat18 = np.repeat(df18.index.values,df18['عدد الحوادث'])
df18repeat = df18.iloc[repeat18].reset_index(drop=True)
df18repeat
# Out:
#        تاريخ الحادث  سنة الحادث      نوع تقرير الحادث      المدينة  \
# 0        31/12/2018        2018      حادث سير بإصابات       ابوظبي
# 1        31/12/2018        2018      حادث سير بإصابات       ابوظبي
# 2        31/12/2018        2018      حادث سير بإصابات  منطقة العين
# 3        31/12/2018        2018  حادث سير بدون إصابات       ابوظبي
# 4        31/12/2018        2018  حادث سير بدون إصابات       ابوظبي
# ...             ...         ...                   ...          ...
# 188454   31/03/2018        2018  حادث سير بدون إصابات  منطقة العين
# 188455   31/03/2018        2018  حادث سير بدون إصابات  منطقة العين
# 188456   31/03/2018        2018  حادث سير بدون إصابات  منطقة العين
# 188457   31/03/2018        2018  حادث سير بدون إصابات  منطقة العين
# 188458   31/03/2018        2018  حادث سير بدون إصابات  منطقة العين
#
#                                                    الشارع  \
# 0                          شارع راشد بن سعيد آل مكتوم (2)
# ...

# %%
repeat19 = np.repeat(df19.index.values,df19['عدد الحوادث'])
df19repeat = df19.iloc[repeat19].reset_index(drop=True)
df19repeat
# Out:
#                تاريخ الحادث  سنة الحادث      نوع تقرير الحادث       المدينة  \
# 0       2019-02-10 00:00:00        2019      حادث سير بإصابات  منطقة الظفرة
# 1       2019-02-10 00:00:00        2019      حادث سير بإصابات   منطقة العين
# 2       2019-02-10 00:00:00        2019      حادث سير بإصابات        أبوظبي
# 3       2019-02-10 00:00:00        2019      حادث سير بإصابات        أبوظبي
# 4       2019-02-10 00:00:00        2019      حادث سير بإصابات        أبوظبي
# ...                     ...         ...                   ...           ...
# 181917           16/08/2019        2019  حادث سير بدون إصابات        أبوظبي
# 181918           16/08/2019        2019  حادث سير بدون إصابات        أبوظبي
# 181919           16/08/2019        2019  حادث سير بدون إصابات        أبوظبي
# 181920           16/08/2019        2019  حادث سير بدون إصابات        أبوظبي
# 181921           16/08/2019        2019  حادث سير بدون إصابات        أبوظبي
#
# ...

# %%
repeat20 = np.repeat(df20.index.values,df20['عدد الحوادث'])
df20repeat = df20.iloc[repeat20].reset_index(drop=True)
df20repeat
# Out:
#        تاريخ الحادث  سنة الحادث      نوع تقرير الحادث       المدينة  \
# 0        17/03/2020        2020      حادث سير بإصابات  منطقة الظفرة
# 1        17/03/2020        2020      حادث سير بإصابات   منطقة العين
# 2        17/03/2020        2020      حادث سير بإصابات        أبوظبي
# 3        17/03/2020        2020      حادث سير بإصابات        أبوظبي
# 4        17/03/2020        2020      حادث سير بإصابات        أبوظبي
# ...             ...         ...                   ...           ...
# 140489   19/06/2020        2020  حادث سير بدون إصابات        أبوظبي
# 140490   19/06/2020        2020  حادث سير بدون إصابات        أبوظبي
# 140491   19/06/2020        2020  حادث سير بدون إصابات        أبوظبي
# 140492   19/06/2020        2020  حادث سير بدون إصابات        أبوظبي
# 140493   19/06/2020        2020  حادث سير بدون إصابات        أبوظبي
#
#                                                  الشارع  \
# 0                                            شارع غياثي
# ...

# %%
df = pd.concat([df16repeat,df17repeat,df18repeat,df19repeat,df20repeat],axis=0)
df
# Out:
#        تاريخ الحادث  سنة الحادث      نوع تقرير الحادث       المدينة  \
# 0        13/01/2016        2016      حادث سير بإصابات        ابوظبي
# 1        13/01/2016        2016      حادث سير بإصابات        ابوظبي
# 2        13/01/2016        2016      حادث سير بإصابات        ابوظبي
# 3        13/01/2016        2016      حادث سير بإصابات        ابوظبي
# 4        13/01/2016        2016      حادث سير بإصابات  منطقة الظفرة
# ...             ...         ...                   ...           ...
# 140489   19/06/2020        2020  حادث سير بدون إصابات        أبوظبي
# 140490   19/06/2020        2020  حادث سير بدون إصابات        أبوظبي
# 140491   19/06/2020        2020  حادث سير بدون إصابات        أبوظبي
# 140492   19/06/2020        2020  حادث سير بدون إصابات        أبوظبي
# 140493   19/06/2020        2020  حادث سير بدون إصابات        أبوظبي
#
#                            الشارع                  نوع الحادث  \
# 0        شارع الشيخ مكتوم بن راشد    صدم جسم ثابت خارج الطريق
# ...

# %%
df.isna().sum()
# Out:
# تاريخ الحادث        0
# سنة الحادث          0
# نوع تقرير الحادث    0
# المدينة             0
# الشارع              0
# نوع الحادث          0
# سبب الحادث          0
# حالة السطح          0
# حالة الطقس          0
# عدد الحوادث         0
# عدد الاصابات        0
# dtype: int64

# %% [markdown]
# # الحوادث المرورية حسب الاعوام

# %%
years = df['سنة الحادث'].value_counts().rename('المجموع').to_frame()
years.loc['المجموع'] = years['المجموع'].sum()
years['النسبة'] = (years['المجموع']/len(df)*100).round(2)
years.columns.name ='سنة الحادث'
years
# Out:
# سنة الحادث  المجموع  النسبة
# 2016         231966   24.29
# 2017         212078   22.21
# 2018         188459   19.74
# 2019         181922   19.05
# 2020         140494   14.71
# المجموع      954919  100.00

# %% [markdown]
# # الحوادث المرورية حسب المدن

# %%
df['المدينة'].value_counts()
# Out:
# ابوظبي          447085
# منطقة العين     249141
# أبوظبي          227141
# منطقة الظفرة     31552
# Name: المدينة, dtype: int64

# %%
df['المدينة'] = df['المدينة'].replace({'ابوظبي':'أبوظبي'})
cities = df['المدينة'].value_counts().rename('المجموع').to_frame()
cities.loc['المجموع'] = cities['المجموع'].sum()
cities['النسبة'] =(cities['المجموع']/len(df)*100).round(2)
cities.columns.name = 'المدينة'
cities
# Out:
# المدينة       المجموع  النسبة
# أبوظبي         674226   70.61
# منطقة العين    249141   26.09
# منطقة الظفرة    31552    3.30
# المجموع        954919  100.00

# %% [markdown]
# # الحوادث المرورية حسب الاعوام والمدن

# %%
accidents = df.pivot_table(index='سنة الحادث',columns='المدينة',aggfunc='size')
accidents['المجموع']= accidents['أبوظبي'] + accidents['منطقة الظفرة'] + accidents['منطقة العين']
accidents.loc['المجموع'] = accidents['أبوظبي'].sum(), accidents['منطقة الظفرة'].sum(), accidents['منطقة العين'].sum(), accidents['المجموع'].sum()
accidents.columns.name = ''
accidents
# Out:
#             أبوظبي  منطقة الظفرة  منطقة العين  المجموع
# سنة الحادث
# 2016        163727          9240        58999   231966
# 2017        150305          6760        55013   212078
# 2018        133053          5670        49736   188459
# 2019        128660          4826        48436   181922
# 2020         98481          5056        36957   140494
# المجموع     674226         31552       249141   954919

# %%
df['سبب الحادث'].value_counts()
# Out:
# عدم ترك مسافة كافية                                         256979
# الاهمال وعدم الانتباه                                       171022
# الرجوع للخلف بدون انتباه                                    157744
# عدم الإلتزام بخط السير الالزامي                             100736
# الرجوع للخلف دون التأكد من خلو الطريق                        64321
# عدم إفساح الطريق / عدم إعطاء الألوية                         46969
# الإنحراف المفاجئ                                             41039
# عدم الإلتزام بخط الطريق                                      29496
# عدم التقيد بالاشارات المرورية                                16535
# عيوب أخرى                                                    16487
# دخول طريق رئيسي دون التأكد من خلوه                           16204
# عدم التقيد بإشارة قف                                          5454
# اللامبالاة                                                    4231
# التجاوز في مكان ممنوع فيه التجاوز                             3979
# ...

# %%
df['سبب الحادث'] = df['سبب الحادث'].replace({'القيادة بدون رخصة قيادة':'القيادة بدون رخصة قيادة إطلاقا'
                                             , 'تحت تأثير مسكر أو مخدر':'القيادة تحت تأثير مسكر أو مخدر'
                                             ,'عدم الإلتزام بخط الطريق':'عدم الإلتزام بخط السير الالزامي',       
'عدم افساح المسار للقادم للخلف بالمرور من الجهة اليسرى':'عدم افساح المسار للقادم من الخلف بالمرور من الجهة اليسرى',
                                          'عدم إعطاء الالوية لعبور المشاة':'عدم إعطاء الاولوية لعبور المشاة',
                                            'عدم صلاحيه الاطارات اثناء السير':'عدم صلاحية الاطارات اثناء السير',
                                            'سقوط حموله غير موثوقه':'عدم تثبيت الحمولة أو بروزها',
                                           'تجاوز السرعة الزائدة' : 'عدم الالتزام بالسرعة المقررة',
                                            'عدم التقيد بإشارات مرورية أخرى':'عدم التقيد بالاشارات المرورية',
                                             'عدم التقيد بإشارة قف':'عدم التقيد بالاشارات المرورية',
                                             'الرجوع للخلف بدون انتباه':'الرجوع للخلف بدون الإنتباه أو التأكد من خلو الطريق',
                                             'الرجوع للخلف دون التأكد من خلو الطريق':'الرجوع للخلف بدون الإنتباه أو التأكد من خلو الطريق',
                                            'تجاوز الإشارة الضوئية الحمراء -- اشارة السهم' : 'تجاوز الإشارة الضوئية الحمراء',
                                            'السوق بطيش وتهور':'اللامبالاة',
                                             'عدم إفساح الطريق / عدم إعطاء الألوية':'عدم إفساح الطريق / عدم إعطاء الأولوية',
                                            'وجود بروز بالطريق أو حفرة واسعة':'عيوب في الطريق',
                                            'عوائق تحجب رؤية الطريق':'إنحجاب الرؤية',
                                            'الانشغال عن الطريق أثناء قيادة المركبة باستعمال الهاتف':'الانشغال عن الطريق أثناء قيادة المركبة بأي صورة كانت'}).replace(['إنفجار إطار','فتح غطاء المحرك أثناء السير','إنفصال احد العجلات أثناء السير','عطل في مثبت السرعة'],'حدوث عطل ميكانيكي أثناء السير').replace(['عدم صلاحية الفرامل','عدم صلاحية الاطارات اثناء السير'],'عيوب في المركبة')


df['سبب الحادث'] = df['سبب الحادث'].replace(['إنفجار إطار','فتح غطاء المحرك أثناء السير','إنفصال احد العجلات أثناء السير','عطل في مثبت السرعة'],'حدوث عطل ميكانيكي أثناء السير').replace(['عدم صلاحية الفرامل','عدم صلاحية الاطارات اثناء السير'],'عيوب في المركبة')

# %% [markdown]
# #### تم إدراج ٤ أسباب ضمن حدوث عطل ميكانيكي أثناء السير
#
#
# * إنفجار إطار
# * فتح غطاء المحرك أثناء السير
# * إنفصال احد العجلات أثناء السير
# * عطل في مثبت السرعة
#
# #### تم إدراج سببين ضمن عيوب في المركبة
#
# * عدم صلاحية الاطارات اثناء السير
# * عدم صلاحية الفرامل

# %% [markdown]
# # أسباب الحوادث

# %%
reasons = df['سبب الحادث'].value_counts().rename('المجموع').to_frame()
reasons.loc['المجموع']= reasons['المجموع'].sum()
reasons['النسبة'] = (reasons['المجموع'] / len(df) *100).round(2)
reasons.index.name = 'سبب الحادث'
reasons
# Out:
#                                                     المجموع  النسبة
# سبب الحادث
# عدم ترك مسافة كافية                                  256979   26.91
# الرجوع للخلف بدون الإنتباه أو التأكد من خلو الطريق   222065   23.25
# الاهمال وعدم الانتباه                                171022   17.91
# عدم الإلتزام بخط السير الالزامي                      130232   13.64
# عدم إفساح الطريق / عدم إعطاء الأولوية                 46969    4.92
# الإنحراف المفاجئ                                      41039    4.30
# عدم التقيد بالاشارات المرورية                         22150    2.32
# عيوب أخرى                                             16487    1.73
# دخول طريق رئيسي دون التأكد من خلوه                    16204    1.70
# اللامبالاة                                             4245    0.44
# التجاوز في مكان ممنوع فيه التجاوز                      3979    0.42
# تجاوز الإشارة الضوئية الحمراء                          3549    0.37
# حدوث عطل ميكانيكي أثناء السير                          3386    0.35
# ...

# %% [markdown]
# ### أسباب الحوادث حسب الأعوام

# %%
reasons = df.pivot_table(index='سبب الحادث',columns='سنة الحادث',aggfunc='size').fillna(0).astype(int)
reasons['المجموع'] = reasons[2016]+reasons[2017]+reasons[2018]+reasons[2019]+reasons[2020]
reasons.sort_values(by='المجموع',ascending=False,inplace = True)
reasons.loc['المجموع'] = reasons[2016].sum(),reasons[2017].sum(),reasons[2018].sum(),reasons[2019].sum(),reasons[2020].sum(),reasons['المجموع'].sum()
reasons.columns.name = ''
reasons
# Out:
#                                                       2016    2017    2018  \
# سبب الحادث
# عدم ترك مسافة كافية                                  59476   57129   52675
# الرجوع للخلف بدون الإنتباه أو التأكد من خلو الطريق   54448   50146   43891
# الاهمال وعدم الانتباه                                44688   38381   30783
# عدم الإلتزام بخط السير الالزامي                      29675   27392   26435
# عدم إفساح الطريق / عدم إعطاء الأولوية                 9352    9155   10051
# الإنحراف المفاجئ                                     11979    9331    7305
# عدم التقيد بالاشارات المرورية                         5535    4802    4339
# عيوب أخرى                                             5858    5084    3001
# دخول طريق رئيسي دون التأكد من خلوه                    4476    3631    2932
# اللامبالاة                                              30    1005    1745
# التجاوز في مكان ممنوع فيه التجاوز                      953     861     754
# ...

# %% [markdown]
# ### أسباب الحوادث حسب المدن

# %%
reasons = df.pivot_table(index='سبب الحادث',columns='المدينة',aggfunc='size').fillna(0).astype(int)
reasons['المجموع']= reasons['أبوظبي']+reasons['منطقة الظفرة']+reasons['منطقة العين']
reasons.sort_values(by='المجموع',ascending=False,inplace=True)
reasons.loc['المجموع']= reasons['أبوظبي'].sum(),reasons['منطقة الظفرة'].sum(),reasons['منطقة العين'].sum(),reasons['المجموع'].sum()
reasons.columns.name = ''
reasons
# Out:
#                                                     أبوظبي  منطقة الظفرة  \
# سبب الحادث
# عدم ترك مسافة كافية                                 189196          2409
# الرجوع للخلف بدون الإنتباه أو التأكد من خلو الطريق  151528          9462
# الاهمال وعدم الانتباه                               128176          7347
# عدم الإلتزام بخط السير الالزامي                      89720          3221
# عدم إفساح الطريق / عدم إعطاء الأولوية                29159           995
# الإنحراف المفاجئ                                     27279          3381
# عدم التقيد بالاشارات المرورية                        15972           233
# عيوب أخرى                                            10410           639
# دخول طريق رئيسي دون التأكد من خلوه                   12383           479
# اللامبالاة                                            3893            28
# التجاوز في مكان ممنوع فيه التجاوز                     2398           102
# تجاوز الإشارة الضوئية الحمراء                         3101            10
# ...

# %% [markdown]
# # أنواع الحوادث

# %%
Acc_types = df['نوع الحادث'].value_counts().rename('المجموع').to_frame()
Acc_types.loc['المجموع'] = Acc_types['المجموع'].sum()
Acc_types['النسبة'] = (Acc_types['المجموع'] / len(df)*100).round(2)
Acc_types.index.name = 'نوع الحادث'
Acc_types
# Out:
#                               المجموع  النسبة
# نوع الحادث
# صدم جانبي                      292879   30.67
# صدم متتالي                     259138   27.14
# صدم خلفي                       189549   19.85
# صدم جسم ثابت خارج الطريق        87205    9.13
# صدم عمودي                       36921    3.87
# صدم جسم ثابت في الطريق          31981    3.35
# أخرى                            27654    2.90
# تدهور                            8684    0.91
# صدم متقابل                       6312    0.66
# صدم جسم غير ثابت في الطريق       5054    0.53
# صدم جسم غير ثابت خارج الطريق     3084    0.32
# دهس إنسان                        2236    0.23
# صدم حيوان                        1798    0.19
# سقوط                              875    0.09
# صدم إثناء الدوران                 761    0.08
# صدم غير متحرك                     560    0.06
# انفصال مقطورة                     158    0.02
# إحتراق                             65    0.01
# غير معروف                           5    0.00
# ...

# %% [markdown]
# ### أنواع الحوادث حسب الأعوام

# %%
AccidentType = df.pivot_table(index='نوع الحادث' ,columns='سنة الحادث' ,aggfunc='size').fillna(0).astype(int)
AccidentType['المجموع'] = AccidentType[2016]+AccidentType[2017]+AccidentType[2018]+AccidentType[2019]+AccidentType[2020]
AccidentType.sort_values(by='المجموع',ascending=False,inplace=True)
AccidentType.loc['المجموع'] = AccidentType[2016].sum(),AccidentType[2017].sum(),AccidentType[2018].sum(),AccidentType[2019].sum(),AccidentType[2020].sum(),AccidentType['المجموع'].sum()
AccidentType.columns.name = ''
AccidentType
# Out:
#                                 2016    2017    2018    2019    2020  المجموع
# نوع الحادث
# صدم جانبي                      74275   63921   56510   55605   42568   292879
# صدم متتالي                     61212   57786   52591   51280   36269   259138
# صدم خلفي                       45381   42215   37725   34975   29253   189549
# صدم جسم ثابت خارج الطريق       22392   20180   16575   15625   12433    87205
# صدم عمودي                       8480    7751    7648    7438    5604    36921
# صدم جسم ثابت في الطريق          7018    7101    6450    6150    5262    31981
# أخرى                            6405    6311    5227    5220    4491    27654
# تدهور                           1911    1819    1670    1775    1509     8684
# صدم متقابل                      1557    1511    1167    1148     929     6312
# صدم جسم غير ثابت في الطريق      1137    1210     975     965     767     5054
# صدم جسم غير ثابت خارج الطريق     677     839     652     492     424     3084
# ...

# %% [markdown]
# ### أنواع الحوادث حسب المدن

# %%
AccidentType = df.pivot_table(index='نوع الحادث' ,columns='المدينة' ,aggfunc='size').fillna(0).astype(int)
AccidentType['المجموع'] = AccidentType['أبوظبي']+AccidentType['منطقة الظفرة']+AccidentType['منطقة العين']
AccidentType.sort_values(by='المجموع',ascending=False,inplace=True)
AccidentType.loc['المجموع'] = AccidentType['أبوظبي'].sum(),AccidentType['منطقة الظفرة'].sum(),AccidentType['منطقة العين'].sum(),AccidentType['المجموع'].sum()
AccidentType.columns.name = ''
AccidentType
# Out:
#                               أبوظبي  منطقة الظفرة  منطقة العين  المجموع
# نوع الحادث
# صدم جانبي                     208630          7881        76368   292879
# صدم متتالي                    192877          1921        64340   259138
# صدم خلفي                      126493          8142        54914   189549
# صدم جسم ثابت خارج الطريق       59150          5517        22538    87205
# صدم عمودي                      25927          1291         9703    36921
# صدم جسم ثابت في الطريق         24247           838         6896    31981
# أخرى                           19211          2599         5844    27654
# تدهور                           4461          1216         3007     8684
# صدم متقابل                      3821           362         2129     6312
# صدم جسم غير ثابت في الطريق      3834           430          790     5054
# صدم جسم غير ثابت خارج الطريق    2244           212          628     3084
# دهس إنسان                       1377            78          781     2236
# ...

# %%
df['حالة السطح'].value_counts()
# Out:
# معبد                        765568
# صحو                         138277
# جاف                          40161
# ترابي                         4183
# مبتل                          2798
# غير معبد                      1331
# مغطى بالرمال                  1195
# ممطر                           934
# أخرى (حدد)                     188
# يوجد مطبات                      91
# ضباب                            64
# مواد بترولية أو كيميائية        46
# مغبر                            37
# عاصف                            23
# غيرمعروف                        14
# غير معروف                        5
# غائم                             4
# Name: حالة السطح, dtype: int64

# %%
df[df['حالة السطح']=='غير معروف'].head()
# Out:
#                تاريخ الحادث  سنة الحادث      نوع تقرير الحادث المدينة  \
# 8488             24/10/2020        2020  حادث سير بدون إصابات  أبوظبي
# 66706            15/11/2020        2020  حادث سير بدون إصابات  أبوظبي
# 72294   2020-06-04 00:00:00        2020  حادث سير بدون إصابات  أبوظبي
# 121332           22/11/2020        2020  حادث سير بدون إصابات  أبوظبي
# 137132  2020-02-06 00:00:00        2020  حادث سير بدون إصابات  أبوظبي
#
#                         الشارع نوع الحادث  \
# 8488         طرق المطار الدولي  صدم جانبي
# 66706      شارع المفرق الشوامخ   صدم خلفي
# 72294       شارع آل نهيان (26)       أخرى
# 121332      شارع آل نهيان (26)   صدم خلفي
# 137132  IP38C تقاطع أبوظبي مول  صدم جانبي
#
#                                                سبب الحادث حالة السطح  \
# 8488                                الاهمال وعدم الانتباه  غير معروف
# 66706   الرجوع للخلف بدون الإنتباه أو التأكد من خلو ال...  غير معروف
# 72294                     عدم الإلتزام بخط السير الالزامي  غير معروف
# ...

# %%
df[df['حالة السطح']=='أخرى (حدد)'].head()
# Out:
#       تاريخ الحادث  سنة الحادث      نوع تقرير الحادث       المدينة  \
# 3208    13/05/2016        2016  حادث سير بدون إصابات   منطقة العين
# 8907    14/02/2016        2016  حادث سير بدون إصابات   منطقة العين
# 14452   14/12/2016        2016      حادث سير بإصابات  منطقة الظفرة
# 14601   14/12/2016        2016  حادث سير بدون إصابات        أبوظبي
# 22099   15/12/2016        2016  حادث سير بدون إصابات   منطقة العين
#
#                     الشارع                    نوع الحادث  \
# 3208   شارع الساد - سويحان  صدم جسم غير ثابت خارج الطريق
# 8907          شارع الاتحاد        صدم جسم ثابت في الطريق
# 14452         لايوجد تعريف                         تدهور
# 14601  شارع المفرق الشوامخ                          أخرى
# 22099   شارع هزاع بن سلطان                          أخرى
#
#                                               سبب الحادث  حالة السطح  \
# 3208   الرجوع للخلف بدون الإنتباه أو التأكد من خلو ال...  أخرى (حدد)
# 8907                               الاهمال وعدم الانتباه  أخرى (حدد)
# ...

# %%
df['حالة السطح'].value_counts().index
# weather condtions :    ['صحو','ممطر','ضباب','غائم','غير معروف','عاصف','مغبر']
# Out:
# Index(['معبد', 'صحو', 'جاف', 'ترابي', 'مبتل', 'غير معبد', 'مغطى بالرمال',
#        'ممطر', 'أخرى (حدد)', 'يوجد مطبات', 'ضباب', 'مواد بترولية أو كيميائية',
#        'مغبر', 'عاصف', 'غيرمعروف', 'غير معروف', 'غائم'],
#       dtype='object')

# %%
df['حالة الطقس'].value_counts().index
# surface  condtions : 
#['معبد','جاف','مبتل','ترابي','مغطى بالرمال','أخرى (حدد)','غير معبد','غيرمعروف','يوجد مطبات','مواد بترولية أو كيميائية']
# Out:
# Index(['صحو', 'معبد', 'جاف', 'ممطر', 'ضباب', 'مبتل', 'ترابي', 'مغبر',
#        'مغطى بالرمال', 'عاصف', 'غير معبد', 'غائم', 'رطب أوندى', 'أخرى (حدد)',
#        'غير معروف', 'غيرمعروف', 'يوجد مطبات', 'مواد بترولية أو كيميائية'],
#       dtype='object')

# %%
surface  = df['حالة السطح'].value_counts().to_frame()
lst = []
w_lst = ['صحو','ممطر','ضباب','مغبر','عاصف','غائم','غير معروف']
for i in surface.index:
    if  i in w_lst:
        lst.append(surface .loc[i,'حالة السطح'])

sum(lst)
# Out:
# 139344

# %%
weather = df['حالة الطقس'].value_counts().to_frame()
lst = []
s_lst = ['ترابي','مبتل','جاف','معبد','غير معبد','مغطى بالرمال','مواد بترولية أو كيميائية','يوجد مطبات','غيرمعروف','أخرى (حدد)']

for i in weather.index:
    if i in s_lst:
        lst.append(weather.loc[i,'حالة الطقس'])
sum(lst)
# Out:
# 139344

# %%
x  = df['حالة السطح'].isin(['صحو','ممطر','ضباب','مغبر','عاصف','غائم','رطب أوندى','غير معروف'])
df.loc[x, ['حالة السطح', 'حالة الطقس']] = df.loc[x, ['حالة الطقس', 'حالة السطح']].values

# %% [markdown]
# # حالة السطح أو الأرضية أثناء وقوع الحادث

# %%
surface = df['حالة السطح'].value_counts().rename('المجموع').to_frame()
surface.loc['المجموع'] = surface['المجموع'].sum()
surface['النسبة'] = (surface['المجموع'] / len(df) * 100).round(2)
surface.index.name = 'حالة السطح'
surface
# Out:
#                           المجموع  النسبة
# حالة السطح
# معبد                       899780   94.23
# جاف                         43875    4.59
# ترابي                        4651    0.49
# مبتل                         3329    0.35
# غير معبد                     1497    0.16
# مغطى بالرمال                 1397    0.15
# أخرى (حدد)                    209    0.02
# يوجد مطبات                    103    0.01
# مواد بترولية أو كيميائية       49    0.01
# غيرمعروف                       29    0.00
# المجموع                    954919  100.00

# %% [markdown]
# ### حالة السطح حسب الأعوام

# %%
surface  = df.pivot_table(index='حالة السطح' , columns='سنة الحادث' , aggfunc='size').fillna(0).astype(int)
surface ['المجموع'] = surface[2016]+ surface[2017]+ surface[2018]+ surface[2019]+ surface[2020]
surface .sort_values(by= 'المجموع', ascending=False , inplace = True)
surface.loc['المجموع'] = surface[2016].sum() ,surface[2017].sum() , surface[2018].sum() , surface[2019].sum(),surface[2020].sum(),surface['المجموع'].sum()
surface['النسبة'] = (surface['المجموع'] / len(df) * 100).round(2)
surface.columns.name =''
surface
# Out:
#                             2016    2017    2018    2019    2020  المجموع  \
# حالة السطح
# معبد                      212850  198618  180251  173759  134302   899780
# جاف                        14573   10783    7056    6720    4743    43875
# ترابي                       2075     985     579     537     475     4651
# مبتل                        1301     907     141     433     547     3329
# غير معبد                     562     362     199     206     168     1497
# مغطى بالرمال                 491     303     177     221     205     1397
# أخرى (حدد)                    65      78      27      16      23      209
# يوجد مطبات                    30      25      17      19      12      103
# مواد بترولية أو كيميائية      17      11       9       8       4       49
# غيرمعروف                       2       6       3       3      15       29
# المجموع                   231966  212078  188459  181922  140494   954919
#
#                           النسبة
# حالة السطح
# ...

# %% [markdown]
# ### حالة السطح حسب المدن

# %%
surface = df.pivot_table(index='حالة السطح' , columns='المدينة' , aggfunc='size').fillna(0).astype(int)
surface['المجموع']= surface['أبوظبي'] + surface['منطقة الظفرة'] + surface['منطقة العين']
surface.sort_values(by='المجموع',ascending=False,inplace=True)
surface.loc['المجموع']= surface['أبوظبي'].sum(), surface['منطقة الظفرة'].sum() , surface['منطقة العين'].sum(),surface['المجموع'].sum()
surface.columns.name =''
surface
# Out:
#                           أبوظبي  منطقة الظفرة  منطقة العين  المجموع
# حالة السطح
# معبد                      653156         18257       228367   899780
# جاف                        16228         11273        16374    43875
# ترابي                       1696          1310         1645     4651
# مبتل                        1774           267         1288     3329
# غير معبد                     748           166          583     1497
# مغطى بالرمال                 497           236          664     1397
# أخرى (حدد)                    60            33          116      209
# يوجد مطبات                    17             4           82      103
# مواد بترولية أو كيميائية      30             6           13       49
# غيرمعروف                      20             0            9       29
# المجموع                   674226         31552       249141   954919

# %% [markdown]
# # حالة الطقس أثناء وقوع الحادث

# %%
weather = df['حالة الطقس'].value_counts().rename('المجموع').to_frame()
weather.loc['المجموع'] = weather['المجموع'].sum()
weather['النسبة'] = (weather['المجموع'] / len(df) * 100).round(2)
weather.columns.name = 'حالة الطقس'
weather
# Out:
# حالة الطقس  المجموع  النسبة
# صحو          948217   99.30
# ممطر           4549    0.48
# ضباب           1413    0.15
# مغبر            338    0.04
# عاصف            218    0.02
# غائم            119    0.01
# رطب أوندى        40    0.00
# غير معروف        25    0.00
# المجموع      954919  100.00

# %% [markdown]
# ### حالة الطقس حسب الأعوام

# %%
weather = df.pivot_table(index='حالة الطقس' , columns='سنة الحادث' , aggfunc='size').fillna(0).astype(int)
weather['المجموع'] = weather[2016]+ weather[2017]+ weather[2018]+ weather[2019]+ weather[2020]
weather.sort_values(by= 'المجموع', ascending=False , inplace = True)
weather.loc['المجموع'] = weather[2016].sum() ,weather[2017].sum() , weather[2018].sum() , weather[2019].sum(),weather[2020].sum(),weather['المجموع'].sum()
weather.columns.name =''
weather
# Out:
#               2016    2017    2018    2019    2020  المجموع
# حالة الطقس
# صحو         229846  210188  187893  180891  139399   948217
# ممطر          1346    1160     248     844     951     4549
# ضباب           584     511     202      45      71     1413
# مغبر            85      80      62      74      37      338
# عاصف            58      84      18      35      23      218
# غائم            35      32      25      19       8      119
# رطب أوندى       12      12       4      12       0       40
# غير معروف        0      11       7       2       5       25
# المجموع     231966  212078  188459  181922  140494   954919

# %% [markdown]
# ### حالة الطقس حسب المدن

# %%
weather = df.pivot_table(index = 'حالة الطقس' , columns= 'المدينة' , aggfunc='size').fillna(0).astype(int)
weather['المجموع']= weather['أبوظبي'] + weather['منطقة الظفرة'] + weather['منطقة العين']
weather.sort_values(by='المجموع',ascending=False,inplace=True)
weather.loc['المجموع']= weather['أبوظبي'].sum(),weather['منطقة الظفرة'].sum(),weather['منطقة العين'].sum(),weather['المجموع'].sum()
weather.columns.name =''
weather
# Out:
#             أبوظبي  منطقة الظفرة  منطقة العين  المجموع
# حالة الطقس
# صحو         670464         30925       246828   948217
# ممطر          2387           257         1905     4549
# ضباب          1033           173          207     1413
# مغبر           155            90           93      338
# عاصف            66            97           55      218
# غائم            65             8           46      119
# رطب أوندى       38             2            0       40
# غير معروف       18             0            7       25
# المجموع     674226         31552       249141   954919

# %% [markdown]
# # أنواع تقارير الحوادث

# %%
Rtype = df['نوع تقرير الحادث'].value_counts().rename('المجموع').to_frame()
Rtype.loc['المجموع'] = Rtype['المجموع'].sum()
Rtype['النسبة'] = (Rtype['المجموع']/len(df)*100).round(2)
Rtype.index.name = 'نوع التقرير'
Rtype
# Out:
#                       المجموع  النسبة
# نوع التقرير
# حادث سير بدون إصابات   947240    99.2
# حادث سير بإصابات         7679     0.8
# المجموع                954919   100.0

# %% [markdown]
# ### أنواع تقارير الحوادث حسب الأعوام

# %%
Rtype = df.pivot_table(index='نوع تقرير الحادث',columns='سنة الحادث',aggfunc='size').fillna(0).astype(int)
Rtype['المجموع'] = Rtype[2016]+Rtype[2017]+Rtype[2018]+Rtype[2019]+Rtype[2020]
Rtype.sort_values(by='المجموع',ascending=False,inplace=True)
Rtype.loc['المجموع']= Rtype[2016].sum(),Rtype[2017].sum(),Rtype[2018].sum(),Rtype[2019].sum(),Rtype[2020].sum(),Rtype['المجموع'].sum()
Rtype.columns.name = ''
Rtype
# Out:
#                         2016    2017    2018    2019    2020  المجموع
# نوع تقرير الحادث
# حادث سير بدون إصابات  230227  210545  187003  180121  139344   947240
# حادث سير بإصابات        1739    1533    1456    1801    1150     7679
# المجموع               231966  212078  188459  181922  140494   954919

# %% [markdown]
# ### أنواع تقارير الحوادث حسب المدن

# %%
Rtype = df.pivot_table(index ='نوع تقرير الحادث',columns= 'المدينة',aggfunc='size').fillna(0).astype(int)
Rtype['المجموع']= Rtype['أبوظبي']+Rtype['منطقة الظفرة']+Rtype['منطقة العين']
Rtype.sort_values(by='المجموع',ascending=False,inplace=True)
Rtype.loc['المجموع']= Rtype['أبوظبي'].sum(),Rtype['منطقة الظفرة'].sum(),Rtype['منطقة العين'].sum(),Rtype['المجموع'].sum()
Rtype.columns.name =''
Rtype
# Out:
#                       أبوظبي  منطقة الظفرة  منطقة العين  المجموع
# نوع تقرير الحادث
# حادث سير بدون إصابات  669388         30965       246887   947240
# حادث سير بإصابات        4838           587         2254     7679
# المجموع               674226         31552       249141   954919

# %% [markdown]
# # الشوارع

# %%
Streets = df.pivot_table(index='الشارع' , columns='سنة الحادث' , aggfunc='size').fillna(0).astype(int)
Streets['المجموع'] = Streets[2016]+ Streets[2017]+ Streets[2018]+ Streets[2019]+ Streets[2020]
Streets.sort_values(by= 'المجموع', ascending=False , inplace = True)
Streets.loc['المجموع'] = Streets[2016].sum(), Streets[2017].sum(),Streets[2018].sum(),Streets[2019].sum(), Streets[2020].sum(),Streets['المجموع'].sum()
Streets['النسبة'] = (Streets['المجموع']/len(df)*100).round(3)
Streets.columns.name = ''
Streets
# Out:
#                                                      2016    2017    2018  \
# الشارع
# شارع داخلي                                          40708   37346   34483
# طريق المصفح                                         35155   29303   22082
# طريق أبوظبي - العين                                 12433   11628    9528
# شارع راشد بن سعيد آل مكتوم (2)                      11970   10764   10166
# شارع المفرق الشوامخ                                  9111    9648    9506
# شارع الشرقي (المرور) (4)                            11688   11243    9790
# شارع السلام (8)                                      9709    9735    9891
# طرق المطار الدولي                                    8237    7931    7967
# نقطة تفتيش الحدود الغربية                            5860    6940    8222
# شارع الشيخ مكتوم بن راشد                             7667    7184    6330
# شارع زايد الأول(7)                                   6991    5807    4576
# شارع الخليج العربي(30)                               4714    4273    4177
# ...

# %% [markdown]
# # حوادث الإصابات

# %% [markdown]
# ### حوادث الإصابات حسب الأعوام

# %%
injuries = df[df['نوع تقرير الحادث']=='حادث سير بإصابات']
injuries_years = injuries['سنة الحادث'].value_counts().rename('المجموع').to_frame()
injuries_years.sort_index(ascending=True,inplace=True)
injuries_years.loc['المجموع'] = injuries_years['المجموع'].sum()
injuries_years['النسبة'] = (injuries_years['المجموع']/len(injuries)*100).round(2)
injuries_years.columns.name ='العام'
injuries_years
# Out:
# العام    المجموع  النسبة
# 2016        1739   22.65
# 2017        1533   19.96
# 2018        1456   18.96
# 2019        1801   23.45
# 2020        1150   14.98
# المجموع     7679  100.00

# %% [markdown]
# ### حوادث الإصابات حسب المدن

# %%
injuries_cities = injuries["المدينة"].value_counts().rename('المجموع').to_frame()
injuries_cities.loc['المجموع'] = injuries_cities['المجموع'].sum()
injuries_cities['النسبة'] = (injuries_cities['المجموع']/len(injuries)*100).round(2)
injuries_cities.columns.name ='المدينة'
injuries_cities
# Out:
# المدينة       المجموع  النسبة
# أبوظبي           4838   63.00
# منطقة العين      2254   29.35
# منطقة الظفرة      587    7.64
# المجموع          7679  100.00

# %% [markdown]
# ### أسباب حوادث الإصابات

# %%
injuries_reasons = injuries['سبب الحادث'].value_counts().rename('المجموع').to_frame()
injuries_reasons.loc['المجموع'] = injuries_reasons['المجموع'].sum()
injuries_reasons['النسبة'] = (injuries_reasons['المجموع']/len(injuries)*100).round(2)
injuries_reasons.columns.name ='سبب الحادث'
injuries_reasons
# Out:
# سبب الحادث                                          المجموع  النسبة
# الإنحراف المفاجئ                                       1221   15.90
# عدم ترك مسافة كافية                                    1019   13.27
# عدم تقدير مستعملي الطريق                                674    8.78
# عدم الإلتزام بخط السير الالزامي                         669    8.71
# السرعة دون مراعاة ظروف الطريق                           577    7.51
# الاهمال وعدم الانتباه                                   540    7.03
# تجاوز الإشارة الضوئية الحمراء                           430    5.60
# القيادة تحت تأثير مسكر أو مخدر                          388    5.05
# عدم إعطاء الاولوية لعبور المشاة                         365    4.75
# دخول طريق رئيسي دون التأكد من خلوه                      317    4.13
# الانشغال عن الطريق أثناء قيادة المركبة بأي صورة...      314    4.09
# عدم التقيد بالاشارات المرورية                           167    2.17
# عدم إفساح الطريق / عدم إعطاء الأولوية                   164    2.14
# ...

# %% [markdown]
# ### أنواع حوادث الإصابات

# %%
injuries_types = injuries['نوع الحادث'].value_counts().rename('المجموع').to_frame()
injuries_types.loc['المجموع'] = injuries_types['المجموع'].sum()
injuries_types['النسبة'] = (injuries_types['المجموع']/len(injuries)*100).round(2)
injuries_types.columns.name ='نوع الحادث'
injuries_types
# Out:
# نوع الحادث                    المجموع  النسبة
# صدم خلفي                         1505   19.60
# دهس إنسان                        1390   18.10
# صدم جانبي                        1216   15.84
# تدهور                             975   12.70
# صدم عمودي                         923   12.02
# صدم جسم ثابت خارج الطريق          546    7.11
# صدم جسم ثابت في الطريق            465    6.06
# صدم متقابل                        275    3.58
# صدم متتالي                        164    2.14
# صدم إثناء الدوران                  69    0.90
# صدم حيوان                          59    0.77
# سقوط                               42    0.55
# صدم جسم غير ثابت في الطريق         37    0.48
# صدم جسم غير ثابت خارج الطريق        7    0.09
# صدم غير متحرك                       4    0.05
# انفصال مقطورة                       2    0.03
# المجموع                          7679  100.00

# %% [markdown]
# ### حالة الطقس أثناء وقوع حادث بإصابات

# %%
injuries_weather = injuries['حالة الطقس'].value_counts().rename('المجموع').to_frame()
injuries_weather.loc['المجموع'] = injuries_weather['المجموع'].sum()
injuries_weather['النسبة'] = (injuries_weather['المجموع']/len(injuries)*100).round(2)
injuries_weather.columns.name ='حالة الطقس'
injuries_weather
# Out:
# حالة الطقس  المجموع  النسبة
# صحو            7326   95.40
# ممطر            160    2.08
# ضباب             86    1.12
# غائم             61    0.79
# رطب أوندى        23    0.30
# مغبر             16    0.21
# عاصف              7    0.09
# المجموع        7679  100.00

# %% [markdown]
# ### حالة السطح أوالأرضية أثناء وقوع حادث بإصابات

# %%
injuries_surface = injuries['حالة السطح'].value_counts().rename('المجموع').to_frame()
injuries_surface.loc['المجموع'] = injuries_surface['المجموع'].sum()
injuries_surface['النسبة'] = (injuries_surface['المجموع']/len(injuries)*100).round(2)
injuries_surface.columns.name ='حالة السطح'
injuries_surface
# Out:
# حالة السطح                المجموع  النسبة
# جاف                          6852   89.23
# معبد                          412    5.37
# مبتل                          166    2.16
# ترابي                         149    1.94
# مغطى بالرمال                   58    0.76
# غير معبد                       26    0.34
# أخرى (حدد)                     13    0.17
# يوجد مطبات                      2    0.03
# مواد بترولية أو كيميائية        1    0.01
# المجموع                      7679  100.00

# %% [markdown]
# ### الشوارع التي وقعت بها حوادث بإصابات

# %%
injuries_streets = injuries['الشارع'].value_counts().rename('المجموع').to_frame()
injuries_streets.loc['المجموع'] = injuries_streets['المجموع'].sum()
injuries_streets['النسبة'] = (injuries_streets['المجموع']/len(injuries)*100).round(2)
injuries_streets.columns.name ='الشارع'
injuries_streets
# Out:
# الشارع                                             المجموع  النسبة
# طريق أبوظبي - العين                                    707    9.21
# شارع داخلي                                             653    8.50
# لايوجد تعريف                                           462    6.02
# شارع الشيخ مكتوم بن راشد                               453    5.90
# شارع المفرق الشوامخ                                    450    5.86
# طريق المصفح                                            306    3.98
# طرق المطار الدولي                                      200    2.60
# طريق سويحان                                            196    2.55
# الشارع العام (أبوظبي - السلع)                          195    2.54
# طريق طريف                                              178    2.32
# شارع راشد بن سعيد آل مكتوم (2)                         150    1.95
# شارع الخليج العربي(30)                                 145    1.89
# طريق أم النار / الشهامة                                144    1.88
# ...
